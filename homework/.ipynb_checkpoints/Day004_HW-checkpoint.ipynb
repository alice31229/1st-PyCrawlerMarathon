# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
# txt
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"12144780561","type":"CreateEvent","actor":{"id":18228123,"login":"tiramisuq","display_login":"tiramisuq","gravatar_id":"","url":"https://api.github.com/users/tiramisuq","avatar_url":"https://avatars.githubusercontent.com/u/18228123?"},"repo":{"id":258448590,"name":"openapi-env-test/test-2020042306-js-open-second-run-spec","url":"https://api.github.com/repos/openapi-env-test/test-2020042306-js-open-second-run-spec"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":null,"pusher_type":"user"},"public":true,"created_at":"2020-04-24T08:10:50Z","org":{"id":57889711,"login":"openapi-env-test","gravatar_id":"","url":"https://api.github.com/orgs/openapi-env-test","avatar_url":"https://avatars.githubusercontent.com/u/57889711?"}},{"id":"12144780547","type":"WatchEvent","actor":{"id":26756033,"login":"Autumnscity","display_login":"Autumnscity","gravatar_id":"","url":"https://api.github.com/users/Autumnscity","avatar_url":"https://avatars.githubusercontent.com/u/26756033?"},"repo":{"id":258044807,"name":"perilouswithadollarsign/cstrike15_src","url":"https://api.github.com/repos/perilouswithadollarsign/cstrike15_src"},"payload":{"action":"started"},"public":true,"created_at":"2020-04-24T08:10:50Z"},{"id":"12144780542","type":"PullRequestEvent","actor":{"id":27856297,"login":"dependabot-preview[bot]","display_login":"dependabot-preview","gravatar_id":"","url":"https://api.github.com/users/dependabot-preview[bot]","avatar_url":"https://avatars.githubusercontent.com/u/27856297?"},"repo":{"id":241804237,"name":"VedadM/ReactReduxRouter_Sample","url":"https://api.github.com/repos/VedadM/ReactReduxRouter_Sample"},"payload":{"action":"closed","number":12,"pull_request":{"url":"https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/pulls/12","id":404991163,"node_id":"MDExOlB1bGxSZXF1ZXN0NDA0OTkxMTYz","html_url":"https://github.com/VedadM/ReactReduxRouter_Sample/pull/12","diff_url":"https://github.com/VedadM/ReactReduxRouter_Sample/pull/12.diff","patch_url":"https://github.com/VedadM/ReactReduxRouter_Sample/pull/12.patch","issue_url":"https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/issues/12","number":12,"state":"closed","locked":false,"title":"Bump @testing-library/user-event from 10.0.1 to 10.0.2","user":{"login":"dependabot-preview[bot]","id":27856297,"node_id":"MDM6Qm90Mjc4NTYyOTc=","avatar_url":"https://avatars3.githubusercontent.com/in/2141?v=4","gravatar_id":"","url":"https://api.github.com/users/dependabot-preview%5Bbot%5D","html_url":"https://github.com/apps/dependabot-preview","followers_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/followers","following_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/repos","events_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events","type":"Bot","site_admin":false},"body":"Bumps [@testing-library/user-event](https://github.com/testing-library/user-event) from 10.0.1 to 10.0.2.\\n<details>\\n<summary>Release notes</summary>\\n<p><em>Sourced from <a href=\\"https://github.com/testing-library/user-event/releases\\">@testing-library/user-event\'s releases</a>.</em></p>\\n<blockquote>\\n<h2>v10.0.2</h2>\\n<h2><a href=\\"https://github.com/testing-library/user-event/compare/v10.0.1...v10.0.2\\">10.0.2</a> (2020-04-16)</h2>\\n<h3>Bug Fixes</h3>\\n<ul>\\n<li>🐛 update @testing-library/dom (<a href=\\"https://github.com/testing-library/user-event/commit/ ...

# %%
# json
import json

json.loads(r.text)
# Out:
# [{'id': '12144780561',
#   'type': 'CreateEvent',
#   'actor': {'id': 18228123,
#    'login': 'tiramisuq',
#    'display_login': 'tiramisuq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tiramisuq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18228123?'},
#   'repo': {'id': 258448590,
#    'name': 'openapi-env-test/test-2020042306-js-open-second-run-spec',
#    'url': 'https://api.github.com/repos/openapi-env-test/test-2020042306-js-open-second-run-spec'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z',
#   'org': {'id': 57889711,
#    'login': 'openapi-env-test',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openapi-env-test',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57889711?'}},
#  {'id': '12144780547',
#   'type': 'WatchEvent',
#   'actor': {'id': 26756033,
#    'login': 'Autumnscity',
#    'display_login': 'Autumnscity',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Autumnscity',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26756033?'},
#   'repo': {'id': 258044807,
#    'name': 'perilouswithadollarsign/cstrike15_src',
#    'url': 'https://api.github.com/repos/perilouswithadollarsign/cstrike15_src'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z'},
#  {'id': '12144780542',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 241804237,
#    'name': 'VedadM/ReactReduxRouter_Sample',
#    'url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample'},
#   'payload': {'action': 'closed',
#    'number': 12,
#    'pull_request': {'url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/pulls/12',
#     'id': 404991163,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDA0OTkxMTYz',
#     'html_url': 'https://github.com/VedadM/ReactReduxRouter_Sample/pull/12',
#     'diff_url': 'https://github.com/VedadM/ReactReduxRouter_Sample/pull/12.diff',
#     'patch_url': 'https://github.com/VedadM/ReactReduxRouter_Sample/pull/12.patch',
#     'issue_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/issues/12',
#     'number': 12,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump @testing-library/user-event from 10.0.1 to 10.0.2',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [@testing-library/user-event](https://github.com/testing-library/user-event) from 10.0.1 to 10.0.2.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/testing-library/user-event/releases">@testing-library/user-event\'s releases</a>.</em></p>\n<blockquote>\n<h2>v10.0.2</h2>\n<h2><a href="https://github.com/testing-library/user-event/compare/v10.0.1...v10.0.2">10.0.2</a> (2020-04-16)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>🐛 update @testing-library/dom (<a href="https://github.com/testing-library/user-event/commit/742c0a7a2bef9123adb178d1a9e8b2f899294a41">742c0a7</a>)</li>\n<li>🐛 update babel (<a href="https://github.com/testing-library/user-event/commit/3ee73390ee684ccd29937887431cb58598606dc5">3ee7339</a>)</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/testing-library/user-event/commit/91f051917657755bd11867975509deac30b60d44"><code>91f0519</code></a> Merge pull request <a href="https://github-redirect.dependabot.com/testing-library/user-event/issues/243">#243</a> from testing-library/updates</li>\n<li><a href="https://github.com/testing-library/user-event/commit/0854d9094d0eedfd729599a299fc8d485226a353"><code>0854d90</code></a> chore: 🤖 update regenerator-runtime</li>\n<li><a href="https://github.com/testing-library/user-event/commit/69068e0d500efbe137c3ff2343aeb29592032644"><code>69068e0</code></a> chore: 🤖 update prettier</li>\n<li><a href="https://github.com/testing-library/user-event/commit/742c0a7a2bef9123adb178d1a9e8b2f899294a41"><code>742c0a7</code></a> fix: 🐛 update @testing-library/dom</li>\n<li><a href="https://github.com/testing-library/user-event/commit/10173049b96d41d6fcebe815e166f120c9a7f8da"><code>1017304</code></a> chore: 🤖 update @testing-library/jest-dom</li>\n<li><a href="https://github.com/testing-library/user-event/commit/608fcd67733170aa650a5b2bfe97553d734a54da"><code>608fcd6</code></a> chore: 🤖 update react</li>\n<li><a href="https://github.com/testing-library/user-event/commit/7ef9f7692e849f0a66cf2fac82140d2b3c77cdaf"><code>7ef9f76</code></a> chore: 🤖 update lint-staged</li>\n<li><a href="https://github.com/testing-library/user-event/commit/469e6f97b6f23e7813ef4e6bbf8bd5f14cffe37f"><code>469e6f9</code></a> chore: 🤖 update all-contributors-cli</li>\n<li><a href="https://github.com/testing-library/user-event/commit/3ee73390ee684ccd29937887431cb58598606dc5"><code>3ee7339</code></a> fix: 🐛 update babel</li>\n<li><a href="https://github.com/testing-library/user-event/commit/c659fceea7ba768066a955928d47c1a903840f9d"><code>c659fce</code></a> chore: 🤖 update semantic-release</li>\n<li>Additional commits viewable in <a href="https://github.com/testing-library/user-event/compare/v10.0.1...v10.0.2">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=@testing-library/user-event&package-manager=npm_and_yarn&previous-version=10.0.1&new-version=10.0.2)](https://dependabot.com/compatibility-score/?dependency-name=@testing-library/user-event&package-manager=npm_and_yarn&previous-version=10.0.1&new-version=10.0.2)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@d ...
#     'created_at': '2020-04-17T08:19:39Z',
#     'updated_at': '2020-04-24T08:10:50Z',
#     'closed_at': '2020-04-24T08:10:50Z',
#     'merged_at': None,
#     'merge_commit_sha': 'c2d983c031b6b48166de5d36d146242ce633416a',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 1961160630,
#       'node_id': 'MDU6TGFiZWwxOTYxMTYwNjMw',
#       'url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/pulls/12/commits',
#     'review_comments_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/pulls/12/comments',
#     'review_comment_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/issues/12/comments',
#     'statuses_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/statuses/9bdc56bdeb23e93b5be7afee447e9834261e41de',
#     'head': {'label': 'VedadM:dependabot/npm_and_yarn/testing-library/user-event-10.0.2',
#      'ref': 'dependabot/npm_and_yarn/testing-library/user-event-10.0.2',
#      'sha': '9bdc56bdeb23e93b5be7afee447e9834261e41de',
#      'user': {'login': 'VedadM',
#       'id': 8867101,
#       'node_id': 'MDQ6VXNlcjg4NjcxMDE=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/8867101?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/VedadM',
#       'html_url': 'https://github.com/VedadM',
#       'followers_url': 'https://api.github.com/users/VedadM/followers',
#       'following_url': 'https://api.github.com/users/VedadM/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/VedadM/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/VedadM/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/VedadM/subscriptions',
#       'organizations_url': 'https://api.github.com/users/VedadM/orgs',
#       'repos_url': 'https://api.github.com/users/VedadM/repos',
#       'events_url': 'https://api.github.com/users/VedadM/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/VedadM/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 241804237,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDE4MDQyMzc=',
#       'name': 'ReactReduxRouter_Sample',
#       'full_name': 'VedadM/ReactReduxRouter_Sample',
#       'private': False,
#       'owner': {'login': 'VedadM',
#        'id': 8867101,
#        'node_id': 'MDQ6VXNlcjg4NjcxMDE=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/8867101?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/VedadM',
#        'html_url': 'https://github.com/VedadM',
#        'followers_url': 'https://api.github.com/users/VedadM/followers',
#        'following_url': 'https://api.github.com/users/VedadM/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/VedadM/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/VedadM/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/VedadM/subscriptions',
#        'organizations_url': 'https://api.github.com/users/VedadM/orgs',
#        'repos_url': 'https://api.github.com/users/VedadM/repos',
#        'events_url': 'https://api.github.com/users/VedadM/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/VedadM/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/VedadM/ReactReduxRouter_Sample',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample',
#       'forks_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/forks',
#       'keys_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/teams',
#       'hooks_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/hooks',
#       'issue_events_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/events',
#       'assignees_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/tags',
#       'blobs_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/languages',
#       'stargazers_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/stargazers',
#       'contributors_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/contributors',
#       'subscribers_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/subscribers',
#       'subscription_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/subscription',
#       'commits_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/merges',
#       'archive_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/downloads',
#       'issues_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/deployments',
#       'created_at': '2020-02-20T05:48:58Z',
#       'updated_at': '2020-04-07T15:53:21Z',
#       'pushed_at': '2020-04-24T08:10:48Z',
#       'git_url': 'git://github.com/VedadM/ReactReduxRouter_Sample.git',
#       'ssh_url': 'git@github.com:VedadM/ReactReduxRouter_Sample.git',
#       'clone_url': 'https://github.com/VedadM/ReactReduxRouter_Sample.git',
#       'svn_url': 'https://github.com/VedadM/ReactReduxRouter_Sample',
#       'homepage': None,
#       'size': 7515,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': None,
#       'forks': 0,
#       'open_issues': 3,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'VedadM:master',
#      'ref': 'master',
#      'sha': '2ff9eb9a102a4fcc882f2891041df1a17c7c49a3',
#      'user': {'login': 'VedadM',
#       'id': 8867101,
#       'node_id': 'MDQ6VXNlcjg4NjcxMDE=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/8867101?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/VedadM',
#       'html_url': 'https://github.com/VedadM',
#       'followers_url': 'https://api.github.com/users/VedadM/followers',
#       'following_url': 'https://api.github.com/users/VedadM/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/VedadM/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/VedadM/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/VedadM/subscriptions',
#       'organizations_url': 'https://api.github.com/users/VedadM/orgs',
#       'repos_url': 'https://api.github.com/users/VedadM/repos',
#       'events_url': 'https://api.github.com/users/VedadM/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/VedadM/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 241804237,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDE4MDQyMzc=',
#       'name': 'ReactReduxRouter_Sample',
#       'full_name': 'VedadM/ReactReduxRouter_Sample',
#       'private': False,
#       'owner': {'login': 'VedadM',
#        'id': 8867101,
#        'node_id': 'MDQ6VXNlcjg4NjcxMDE=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/8867101?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/VedadM',
#        'html_url': 'https://github.com/VedadM',
#        'followers_url': 'https://api.github.com/users/VedadM/followers',
#        'following_url': 'https://api.github.com/users/VedadM/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/VedadM/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/VedadM/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/VedadM/subscriptions',
#        'organizations_url': 'https://api.github.com/users/VedadM/orgs',
#        'repos_url': 'https://api.github.com/users/VedadM/repos',
#        'events_url': 'https://api.github.com/users/VedadM/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/VedadM/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/VedadM/ReactReduxRouter_Sample',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample',
#       'forks_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/forks',
#       'keys_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/teams',
#       'hooks_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/hooks',
#       'issue_events_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/events',
#       'assignees_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/tags',
#       'blobs_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/languages',
#       'stargazers_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/stargazers',
#       'contributors_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/contributors',
#       'subscribers_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/subscribers',
#       'subscription_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/subscription',
#       'commits_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/merges',
#       'archive_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/downloads',
#       'issues_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/deployments',
#       'created_at': '2020-02-20T05:48:58Z',
#       'updated_at': '2020-04-07T15:53:21Z',
#       'pushed_at': '2020-04-24T08:10:48Z',
#       'git_url': 'git://github.com/VedadM/ReactReduxRouter_Sample.git',
#       'ssh_url': 'git@github.com:VedadM/ReactReduxRouter_Sample.git',
#       'clone_url': 'https://github.com/VedadM/ReactReduxRouter_Sample.git',
#       'svn_url': 'https://github.com/VedadM/ReactReduxRouter_Sample',
#       'homepage': None,
#       'size': 7515,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 3,
#       'license': None,
#       'forks': 0,
#       'open_issues': 3,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/pulls/12'},
#      'html': {'href': 'https://github.com/VedadM/ReactReduxRouter_Sample/pull/12'},
#      'issue': {'href': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/issues/12'},
#      'comments': {'href': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/issues/12/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/pulls/12/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/pulls/12/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/VedadM/ReactReduxRouter_Sample/statuses/9bdc56bdeb23e93b5be7afee447e9834261e41de'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 8,
#     'deletions': 8,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z'},
#  {'id': '12144780539',
#   'type': 'IssuesEvent',
#   'actor': {'id': 8954519,
#    'login': 'sucheep-s',
#    'display_login': 'sucheep-s',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sucheep-s',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8954519?'},
#   'repo': {'id': 3549545,
#    'name': 'scottgonzalez/node-wordpress',
#    'url': 'https://api.github.com/repos/scottgonzalez/node-wordpress'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/scottgonzalez/node-wordpress/issues/70',
#     'repository_url': 'https://api.github.com/repos/scottgonzalez/node-wordpress',
#     'labels_url': 'https://api.github.com/repos/scottgonzalez/node-wordpress/issues/70/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/scottgonzalez/node-wordpress/issues/70/comments',
#     'events_url': 'https://api.github.com/repos/scottgonzalez/node-wordpress/issues/70/events',
#     'html_url': 'https://github.com/scottgonzalez/node-wordpress/issues/70',
#     'id': 606126547,
#     'node_id': 'MDU6SXNzdWU2MDYxMjY1NDc=',
#     'number': 70,
#     'title': 'Sorry, this file type is not permitted for security reasons.',
#     'user': {'login': 'sucheep-s',
#      'id': 8954519,
#      'node_id': 'MDQ6VXNlcjg5NTQ1MTk=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/8954519?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sucheep-s',
#      'html_url': 'https://github.com/sucheep-s',
#      'followers_url': 'https://api.github.com/users/sucheep-s/followers',
#      'following_url': 'https://api.github.com/users/sucheep-s/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sucheep-s/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sucheep-s/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sucheep-s/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sucheep-s/orgs',
#      'repos_url': 'https://api.github.com/users/sucheep-s/repos',
#      'events_url': 'https://api.github.com/users/sucheep-s/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sucheep-s/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-04-24T08:10:50Z',
#     'updated_at': '2020-04-24T08:10:50Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': "Hi guys, I do an upload job but it returns me error,\r\n\r\n> Error: XML-RPC fault: Could not write file my_file (Sorry, this file type is not permitted for security reasons.).\r\n\r\nHere is my code\r\n\r\n![Snip25630424_5](https://user-images.githubusercontent.com/8954519/80189808-7c043900-863d-11ea-9f74-6a2d2e372ab8.png)\r\n\r\nI've found a solution on the internet that I can put a code\r\n\r\n> define(‘ALLOW_UNFILTERED_UPLOADS’, true);\r\n\r\ninto the config.php\r\n\r\nThis solution can solve the issue but almost comments I've read don't recommend to use this solution due to the security issue.\r\n\r\nIs there another solution to solve. Or I can go this way without any concern ?\r\n"}},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z'},
#  {'id': '12144780531',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 39814207,
#    'login': 'pull[bot]',
#    'display_login': 'pull',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pull[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39814207?'},
#   'repo': {'id': 245535644,
#    'name': 'retroheim/Floodgate',
#    'url': 'https://api.github.com/repos/retroheim/Floodgate'},
#   'payload': {'action': 'closed',
#    'number': 104,
#    'pull_request': {'url': 'https://api.github.com/repos/retroheim/Floodgate/pulls/104',
#     'id': 408398082,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDA4Mzk4MDgy',
#     'html_url': 'https://github.com/retroheim/Floodgate/pull/104',
#     'diff_url': 'https://github.com/retroheim/Floodgate/pull/104.diff',
#     'patch_url': 'https://github.com/retroheim/Floodgate/pull/104.patch',
#     'issue_url': 'https://api.github.com/repos/retroheim/Floodgate/issues/104',
#     'number': 104,
#     'state': 'closed',
#     'locked': False,
#     'title': '[pull] development from GeyserMC:development',
#     'user': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'See [Commits](/retroheim/Floodgate/pull/104/commits) and [Changes](/retroheim/Floodgate/pull/104/files) for more details.\n\n-----\nCreated by [<img src="https://prod.download/pull-18h-svg" valign="bottom"/> **pull[bot]**](https://github.com/wei/pull). Want to support this open source service? [Please star it : )](https://github.com/wei/pull)',
#     'created_at': '2020-04-24T08:10:24Z',
#     'updated_at': '2020-04-24T08:10:50Z',
#     'closed_at': '2020-04-24T08:10:50Z',
#     'merged_at': '2020-04-24T08:10:49Z',
#     'merge_commit_sha': 'fc6ffef9a1f34a9dc81da2a2ba7736b3d6fd3796',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 1898683602,
#       'node_id': 'MDU6TGFiZWwxODk4NjgzNjAy',
#       'url': 'https://api.github.com/repos/retroheim/Floodgate/labels/:arrow_heading_down:%20pull',
#       'name': ':arrow_heading_down: pull',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/retroheim/Floodgate/pulls/104/commits',
#     'review_comments_url': 'https://api.github.com/repos/retroheim/Floodgate/pulls/104/comments',
#     'review_comment_url': 'https://api.github.com/repos/retroheim/Floodgate/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/retroheim/Floodgate/issues/104/comments',
#     'statuses_url': 'https://api.github.com/repos/retroheim/Floodgate/statuses/6bbbe4f350d97f0d611cfc4d28596018e9c84a27',
#     'head': {'label': 'GeyserMC:development',
#      'ref': 'development',
#      'sha': '6bbbe4f350d97f0d611cfc4d28596018e9c84a27',
#      'user': {'login': 'GeyserMC',
#       'id': 52673035,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUyNjczMDM1',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/52673035?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/GeyserMC',
#       'html_url': 'https://github.com/GeyserMC',
#       'followers_url': 'https://api.github.com/users/GeyserMC/followers',
#       'following_url': 'https://api.github.com/users/GeyserMC/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/GeyserMC/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/GeyserMC/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/GeyserMC/subscriptions',
#       'organizations_url': 'https://api.github.com/users/GeyserMC/orgs',
#       'repos_url': 'https://api.github.com/users/GeyserMC/repos',
#       'events_url': 'https://api.github.com/users/GeyserMC/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/GeyserMC/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 224874708,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjQ4NzQ3MDg=',
#       'name': 'Floodgate',
#       'full_name': 'GeyserMC/Floodgate',
#       'private': False,
#       'owner': {'login': 'GeyserMC',
#        'id': 52673035,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUyNjczMDM1',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/52673035?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/GeyserMC',
#        'html_url': 'https://github.com/GeyserMC',
#        'followers_url': 'https://api.github.com/users/GeyserMC/followers',
#        'following_url': 'https://api.github.com/users/GeyserMC/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/GeyserMC/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/GeyserMC/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/GeyserMC/subscriptions',
#        'organizations_url': 'https://api.github.com/users/GeyserMC/orgs',
#        'repos_url': 'https://api.github.com/users/GeyserMC/repos',
#        'events_url': 'https://api.github.com/users/GeyserMC/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/GeyserMC/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/GeyserMC/Floodgate',
#       'description': 'Hybrid mode plugin to allow for connections from Geyser to join online mode servers.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/GeyserMC/Floodgate',
#       'forks_url': 'https://api.github.com/repos/GeyserMC/Floodgate/forks',
#       'keys_url': 'https://api.github.com/repos/GeyserMC/Floodgate/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/GeyserMC/Floodgate/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/GeyserMC/Floodgate/teams',
#       'hooks_url': 'https://api.github.com/repos/GeyserMC/Floodgate/hooks',
#       'issue_events_url': 'https://api.github.com/repos/GeyserMC/Floodgate/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/GeyserMC/Floodgate/events',
#       'assignees_url': 'https://api.github.com/repos/GeyserMC/Floodgate/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/GeyserMC/Floodgate/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/GeyserMC/Floodgate/tags',
#       'blobs_url': 'https://api.github.com/repos/GeyserMC/Floodgate/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/GeyserMC/Floodgate/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/GeyserMC/Floodgate/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/GeyserMC/Floodgate/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/GeyserMC/Floodgate/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/GeyserMC/Floodgate/languages',
#       'stargazers_url': 'https://api.github.com/repos/GeyserMC/Floodgate/stargazers',
#       'contributors_url': 'https://api.github.com/repos/GeyserMC/Floodgate/contributors',
#       'subscribers_url': 'https://api.github.com/repos/GeyserMC/Floodgate/subscribers',
#       'subscription_url': 'https://api.github.com/repos/GeyserMC/Floodgate/subscription',
#       'commits_url': 'https://api.github.com/repos/GeyserMC/Floodgate/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/GeyserMC/Floodgate/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/GeyserMC/Floodgate/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/GeyserMC/Floodgate/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/GeyserMC/Floodgate/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/GeyserMC/Floodgate/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/GeyserMC/Floodgate/merges',
#       'archive_url': 'https://api.github.com/repos/GeyserMC/Floodgate/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/GeyserMC/Floodgate/downloads',
#       'issues_url': 'https://api.github.com/repos/GeyserMC/Floodgate/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/GeyserMC/Floodgate/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/GeyserMC/Floodgate/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/GeyserMC/Floodgate/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/GeyserMC/Floodgate/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/GeyserMC/Floodgate/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/GeyserMC/Floodgate/deployments',
#       'created_at': '2019-11-29T15:01:51Z',
#       'updated_at': '2020-04-23T20:06:49Z',
#       'pushed_at': '2020-04-23T20:08:20Z',
#       'git_url': 'git://github.com/GeyserMC/Floodgate.git',
#       'ssh_url': 'git@github.com:GeyserMC/Floodgate.git',
#       'clone_url': 'https://github.com/GeyserMC/Floodgate.git',
#       'svn_url': 'https://github.com/GeyserMC/Floodgate',
#       'homepage': None,
#       'size': 81,
#       'stargazers_count': 24,
#       'watchers_count': 24,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 14,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 2,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 14,
#       'open_issues': 2,
#       'watchers': 24,
#       'default_branch': 'development'}},
#     'base': {'label': 'retroheim:development',
#      'ref': 'development',
#      'sha': '57a457a7d2a03f521bf66e002aaee2e94342de68',
#      'user': {'login': 'retroheim',
#       'id': 60027238,
#       'node_id': 'MDQ6VXNlcjYwMDI3MjM4',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/60027238?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/retroheim',
#       'html_url': 'https://github.com/retroheim',
#       'followers_url': 'https://api.github.com/users/retroheim/followers',
#       'following_url': 'https://api.github.com/users/retroheim/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/retroheim/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/retroheim/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/retroheim/subscriptions',
#       'organizations_url': 'https://api.github.com/users/retroheim/orgs',
#       'repos_url': 'https://api.github.com/users/retroheim/repos',
#       'events_url': 'https://api.github.com/users/retroheim/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/retroheim/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 245535644,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDU1MzU2NDQ=',
#       'name': 'Floodgate',
#       'full_name': 'retroheim/Floodgate',
#       'private': False,
#       'owner': {'login': 'retroheim',
#        'id': 60027238,
#        'node_id': 'MDQ6VXNlcjYwMDI3MjM4',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/60027238?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/retroheim',
#        'html_url': 'https://github.com/retroheim',
#        'followers_url': 'https://api.github.com/users/retroheim/followers',
#        'following_url': 'https://api.github.com/users/retroheim/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/retroheim/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/retroheim/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/retroheim/subscriptions',
#        'organizations_url': 'https://api.github.com/users/retroheim/orgs',
#        'repos_url': 'https://api.github.com/users/retroheim/repos',
#        'events_url': 'https://api.github.com/users/retroheim/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/retroheim/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/retroheim/Floodgate',
#       'description': 'Hybrid mode plugin to allow for connections from Geyser to join online mode servers.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/retroheim/Floodgate',
#       'forks_url': 'https://api.github.com/repos/retroheim/Floodgate/forks',
#       'keys_url': 'https://api.github.com/repos/retroheim/Floodgate/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/retroheim/Floodgate/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/retroheim/Floodgate/teams',
#       'hooks_url': 'https://api.github.com/repos/retroheim/Floodgate/hooks',
#       'issue_events_url': 'https://api.github.com/repos/retroheim/Floodgate/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/retroheim/Floodgate/events',
#       'assignees_url': 'https://api.github.com/repos/retroheim/Floodgate/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/retroheim/Floodgate/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/retroheim/Floodgate/tags',
#       'blobs_url': 'https://api.github.com/repos/retroheim/Floodgate/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/retroheim/Floodgate/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/retroheim/Floodgate/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/retroheim/Floodgate/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/retroheim/Floodgate/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/retroheim/Floodgate/languages',
#       'stargazers_url': 'https://api.github.com/repos/retroheim/Floodgate/stargazers',
#       'contributors_url': 'https://api.github.com/repos/retroheim/Floodgate/contributors',
#       'subscribers_url': 'https://api.github.com/repos/retroheim/Floodgate/subscribers',
#       'subscription_url': 'https://api.github.com/repos/retroheim/Floodgate/subscription',
#       'commits_url': 'https://api.github.com/repos/retroheim/Floodgate/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/retroheim/Floodgate/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/retroheim/Floodgate/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/retroheim/Floodgate/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/retroheim/Floodgate/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/retroheim/Floodgate/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/retroheim/Floodgate/merges',
#       'archive_url': 'https://api.github.com/repos/retroheim/Floodgate/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/retroheim/Floodgate/downloads',
#       'issues_url': 'https://api.github.com/repos/retroheim/Floodgate/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/retroheim/Floodgate/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/retroheim/Floodgate/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/retroheim/Floodgate/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/retroheim/Floodgate/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/retroheim/Floodgate/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/retroheim/Floodgate/deployments',
#       'created_at': '2020-03-06T23:33:15Z',
#       'updated_at': '2020-04-24T06:09:32Z',
#       'pushed_at': '2020-04-24T08:10:49Z',
#       'git_url': 'git://github.com/retroheim/Floodgate.git',
#       'ssh_url': 'git@github.com:retroheim/Floodgate.git',
#       'clone_url': 'https://github.com/retroheim/Floodgate.git',
#       'svn_url': 'https://github.com/retroheim/Floodgate',
#       'homepage': None,
#       'size': 201,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Java',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'development'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/retroheim/Floodgate/pulls/104'},
#      'html': {'href': 'https://github.com/retroheim/Floodgate/pull/104'},
#      'issue': {'href': 'https://api.github.com/repos/retroheim/Floodgate/issues/104'},
#      'comments': {'href': 'https://api.github.com/repos/retroheim/Floodgate/issues/104/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/retroheim/Floodgate/pulls/104/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/retroheim/Floodgate/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/retroheim/Floodgate/pulls/104/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/retroheim/Floodgate/statuses/6bbbe4f350d97f0d611cfc4d28596018e9c84a27'}},
#     'author_association': 'NONE',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'pull[bot]',
#      'id': 39814207,
#      'node_id': 'MDM6Qm90Mzk4MTQyMDc=',
#      'avatar_url': 'https://avatars0.githubusercontent.com/in/12910?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pull%5Bbot%5D',
#      'html_url': 'https://github.com/apps/pull',
#      'followers_url': 'https://api.github.com/users/pull%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/pull%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pull%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pull%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pull%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pull%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/pull%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/pull%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pull%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 10,
#     'deletions': 1,
#     'changed_files': 4}},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z'},
#  {'id': '12144780532',
#   'type': 'CreateEvent',
#   'actor': {'id': 18228123,
# ...
#    'before': 'a254440154f69ed490149a5bfd0da8bbb9eaa7c9',
#    'commits': [{'sha': '0590e6ddcb1bf1ad48e04f1d05a42ca7d580c505',
#      'author': {'email': 'cloudalchemybot@gmail.com',
#       'name': 'cloudalchemybot'},
#      'message': '[ci skip] Automatic changelog update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cloudalchemy/ansible-alertmanager/commits/0590e6ddcb1bf1ad48e04f1d05a42ca7d580c505'}]},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z',
#   'org': {'id': 30964538,
#    'login': 'cloudalchemy',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cloudalchemy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30964538?'}},
#  {'id': '12144780497',
#   'type': 'DeleteEvent',
#   'actor': {'id': 24863743,
#    'login': 'ashaykapadiya',
#    'display_login': 'ashaykapadiya',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ashaykapadiya',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24863743?'},
#   'repo': {'id': 258446750,
#    'name': 'ashaykapadiya/android_hardware_qcom_audio',
#    'url': 'https://api.github.com/repos/ashaykapadiya/android_hardware_qcom_audio'},
#   'payload': {'ref': 'cm-13.0-caf-8960',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z'},
#  {'id': '12144780496',
#   'type': 'CreateEvent',
#   'actor': {'id': 18228123,
#    'login': 'tiramisuq',
#    'display_login': 'tiramisuq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tiramisuq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18228123?'},
#   'repo': {'id': 258448581,
#    'name': 'openapi-env-test/test-2020042306-js-merged-pr-sdk',
#    'url': 'https://api.github.com/repos/openapi-env-test/test-2020042306-js-merged-pr-sdk'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z',
#   'org': {'id': 57889711,
#    'login': 'openapi-env-test',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openapi-env-test',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57889711?'}},
#  {'id': '12144780490',
#   'type': 'CreateEvent',
#   'actor': {'id': 18228123,
#    'login': 'tiramisuq',
#    'display_login': 'tiramisuq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tiramisuq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18228123?'},
#   'repo': {'id': 258448588,
#    'name': 'openapi-env-test/test-2020042306-js-merged-pr-spec',
#    'url': 'https://api.github.com/repos/openapi-env-test/test-2020042306-js-merged-pr-spec'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z',
#   'org': {'id': 57889711,
#    'login': 'openapi-env-test',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openapi-env-test',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57889711?'}},
#  {'id': '12144780486',
#   'type': 'PushEvent',
#   'actor': {'id': 9155111,
#    'login': 'ashwinvis',
#    'display_login': 'ashwinvis',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ashwinvis',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9155111?'},
#   'repo': {'id': 122968002,
#    'name': 'ashwinvis/ashwinvis.github.io',
#    'url': 'https://api.github.com/repos/ashwinvis/ashwinvis.github.io'},
#   'payload': {'push_id': 4968541019,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '90e33c2bb2555e73abb70888460a215f1149c8fc',
#    'before': '7bae1d0bbb429e0bf6e205c862c54ac88b8c83a8',
#    'commits': [{'sha': '90e33c2bb2555e73abb70888460a215f1149c8fc',
#      'author': {'email': 'ashwinvis@users.noreply.github.com',
#       'name': 'ashwinvis'},
#      'message': 'Automated deployment: Fri Apr 24 08:10:46 UTC 2020 1f4af75f95aec6804065846757768d4ca048c7e8',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ashwinvis/ashwinvis.github.io/commits/90e33c2bb2555e73abb70888460a215f1149c8fc'}]},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z'},
#  {'id': '12144780479',
#   'type': 'CreateEvent',
#   'actor': {'id': 18228123,
#    'login': 'tiramisuq',
#    'display_login': 'tiramisuq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tiramisuq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18228123?'},
#   'repo': {'id': 258448582,
#    'name': 'openapi-env-test/test-2020042306-js-multi-merge-empty-sdk',
#    'url': 'https://api.github.com/repos/openapi-env-test/test-2020042306-js-multi-merge-empty-sdk'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z',
#   'org': {'id': 57889711,
#    'login': 'openapi-env-test',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openapi-env-test',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57889711?'}},
#  {'id': '12144780474',
#   'type': 'CreateEvent',
#   'actor': {'id': 18228123,
#    'login': 'tiramisuq',
#    'display_login': 'tiramisuq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tiramisuq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18228123?'},
#   'repo': {'id': 258448584,
#    'name': 'openapi-env-test/test-2020042306-js-multi-merge-empty-spec',
#    'url': 'https://api.github.com/repos/openapi-env-test/test-2020042306-js-multi-merge-empty-spec'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z',
#   'org': {'id': 57889711,
#    'login': 'openapi-env-test',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openapi-env-test',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57889711?'}},
#  {'id': '12144780478',
#   'type': 'CreateEvent',
#   'actor': {'id': 18228123,
#    'login': 'tiramisuq',
#    'display_login': 'tiramisuq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tiramisuq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18228123?'},
#   'repo': {'id': 258448583,
#    'name': 'openapi-env-test/test-2020042306-js-multi-merge-open-sdk',
#    'url': 'https://api.github.com/repos/openapi-env-test/test-2020042306-js-multi-merge-open-sdk'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z',
#   'org': {'id': 57889711,
#    'login': 'openapi-env-test',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openapi-env-test',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57889711?'}},
#  {'id': '12144780469',
#   'type': 'PushEvent',
#   'actor': {'id': 1422621,
#    'login': 'laxsmi',
#    'display_login': 'laxsmi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/laxsmi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1422621?'},
#   'repo': {'id': 250212872,
#    'name': 'laxsmi/rinemo-bijoux',
#    'url': 'https://api.github.com/repos/laxsmi/rinemo-bijoux'},
#   'payload': {'push_id': 4968541006,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e2fffd25366e75f0391a0b8c4222d1aaf7447511',
#    'before': 'e73dddf8319e7baca2d29341dabdce17b82e1aa1',
#    'commits': [{'sha': 'e2fffd25366e75f0391a0b8c4222d1aaf7447511',
#      'author': {'email': 'thomas@debay.org', 'name': 'Thomas Debay'},
#      'message': 'cart design',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/laxsmi/rinemo-bijoux/commits/e2fffd25366e75f0391a0b8c4222d1aaf7447511'}]},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z'},
#  {'id': '12144780475',
#   'type': 'DeleteEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 249613985,
#    'name': 'Caramella-kr/C0r0n4_r4ng99e',
#    'url': 'https://api.github.com/repos/Caramella-kr/C0r0n4_r4ng99e'},
#   'payload': {'ref': 'build-number-643',
#    'ref_type': 'tag',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z',
#   'org': {'id': 35989831,
#    'login': 'Caramella-kr',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Caramella-kr',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35989831?'}},
#  {'id': '12144780465',
#   'type': 'CreateEvent',
#   'actor': {'id': 18228123,
#    'login': 'tiramisuq',
#    'display_login': 'tiramisuq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tiramisuq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18228123?'},
#   'repo': {'id': 258448580,
#    'name': 'openapi-env-test/test-2020042306-js-opened-pr-spec',
#    'url': 'https://api.github.com/repos/openapi-env-test/test-2020042306-js-opened-pr-spec'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z',
#   'org': {'id': 57889711,
#    'login': 'openapi-env-test',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openapi-env-test',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57889711?'}},
#  {'id': '12144780462',
#   'type': 'DeleteEvent',
#   'actor': {'id': 24863743,
#    'login': 'ashaykapadiya',
#    'display_login': 'ashaykapadiya',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ashaykapadiya',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24863743?'},
#   'repo': {'id': 258446750,
#    'name': 'ashaykapadiya/android_hardware_qcom_audio',
#    'url': 'https://api.github.com/repos/ashaykapadiya/android_hardware_qcom_audio'},
#   'payload': {'ref': 'cm-13.0-caf-8952',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z'},
#  {'id': '12144780460',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 539462,
#    'login': 'enumag',
#    'display_login': 'enumag',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/enumag',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/539462?'},
#   'repo': {'id': 1509011,
#    'name': 'FriendsOfSymfony/FOSRestBundle',
#    'url': 'https://api.github.com/repos/FriendsOfSymfony/FOSRestBundle'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/FriendsOfSymfony/FOSRestBundle/issues/2030',
#     'repository_url': 'https://api.github.com/repos/FriendsOfSymfony/FOSRestBundle',
#     'labels_url': 'https://api.github.com/repos/FriendsOfSymfony/FOSRestBundle/issues/2030/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/FriendsOfSymfony/FOSRestBundle/issues/2030/comments',
#     'events_url': 'https://api.github.com/repos/FriendsOfSymfony/FOSRestBundle/issues/2030/events',
#     'html_url': 'https://github.com/FriendsOfSymfony/FOSRestBundle/issues/2030',
#     'id': 526450308,
#     'node_id': 'MDU6SXNzdWU1MjY0NTAzMDg=',
#     'number': 2030,
#     'title': 'Upgrade to Symfony 4.4.x causes - The "controller_name_converter" service is deprecated since Symfony 4.3',
#     'user': {'login': 'treadmillian',
#      'id': 14092511,
#      'node_id': 'MDQ6VXNlcjE0MDkyNTEx',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/14092511?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/treadmillian',
#      'html_url': 'https://github.com/treadmillian',
#      'followers_url': 'https://api.github.com/users/treadmillian/followers',
#      'following_url': 'https://api.github.com/users/treadmillian/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/treadmillian/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/treadmillian/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/treadmillian/subscriptions',
#      'organizations_url': 'https://api.github.com/users/treadmillian/orgs',
#      'repos_url': 'https://api.github.com/users/treadmillian/repos',
#      'events_url': 'https://api.github.com/users/treadmillian/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/treadmillian/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 10,
#     'created_at': '2019-11-21T08:54:46Z',
#     'updated_at': '2020-04-24T08:10:49Z',
#     'closed_at': '2020-02-07T06:23:24Z',
#     'author_association': 'NONE',
#     'body': '`1x: The "controller_name_converter" service is deprecated since Symfony 4.3. It is being referenced by the "fos_rest.routing.loader.controller" service.\r\n        1x in JsonControllerTest::setUp from App\\Tests\\Controller\\Api\\V1`'},
#    'comment': {'url': 'https://api.github.com/repos/FriendsOfSymfony/FOSRestBundle/issues/comments/618870378',
#     'html_url': 'https://github.com/FriendsOfSymfony/FOSRestBundle/issues/2030#issuecomment-618870378',
#     'issue_url': 'https://api.github.com/repos/FriendsOfSymfony/FOSRestBundle/issues/2030',
#     'id': 618870378,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDYxODg3MDM3OA==',
#     'user': {'login': 'enumag',
#      'id': 539462,
#      'node_id': 'MDQ6VXNlcjUzOTQ2Mg==',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/539462?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/enumag',
#      'html_url': 'https://github.com/enumag',
#      'followers_url': 'https://api.github.com/users/enumag/followers',
#      'following_url': 'https://api.github.com/users/enumag/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/enumag/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/enumag/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/enumag/subscriptions',
#      'organizations_url': 'https://api.github.com/users/enumag/orgs',
#      'repos_url': 'https://api.github.com/users/enumag/repos',
#      'events_url': 'https://api.github.com/users/enumag/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/enumag/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-04-24T08:10:49Z',
#     'updated_at': '2020-04-24T08:10:49Z',
#     'author_association': 'NONE',
#     'body': "> the method specific annotations @Get, @Post and so on won't be removed and will be handled by Symfony's annotation loader\r\n\r\nDoes that mean I can simply change `type: rest` to `type: annotation`?\r\n\r\n> The `2.x` branch mirrors the 2.8 development.\r\n\r\nThere is no 2.x branch."}},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z',
#   'org': {'id': 529709,
#    'login': 'FriendsOfSymfony',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/FriendsOfSymfony',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/529709?'}},
#  {'id': '12144780452',
#   'type': 'PushEvent',
#   'actor': {'id': 56639382,
#    'login': 'okaban',
#    'display_login': 'okaban',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/okaban',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56639382?'},
#   'repo': {'id': 257184532,
#    'name': 'okaban/Kim',
#    'url': 'https://api.github.com/repos/okaban/Kim'},
#   'payload': {'push_id': 4968540993,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f132e3212b4f3cf541d6af50e1c2979ac8b0a05c',
#    'before': '637c5191ed30af91e4c165715171f3a060ef4f9f',
#    'commits': [{'sha': 'f132e3212b4f3cf541d6af50e1c2979ac8b0a05c',
#      'author': {'email': 'tomoki@tomokinoMacBook-7.local', 'name': 'Tomoki'},
#      'message': 'run-sratool.shを修正',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/okaban/Kim/commits/f132e3212b4f3cf541d6af50e1c2979ac8b0a05c'}]},
#   'public': True,
#   'created_at': '2020-04-24T08:10:50Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
# https://cat-fact.herokuapp.com/facts
import requests
import json

r = requests.get("https://cat-fact.herokuapp.com/facts")
json.loads(r.text)
# Out:
# {'all': [{'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a090aac31001185ed16',
#    'text': 'Cats make more than 100 different sounds whereas dogs make around 10.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c489117e4f6130014c987b9',
#    'text': 'Leonardo da Vinci created a series of drawings titled "Study of Cat Movements and Positions", which consists of more than twenty drawings of cats and lions lying a sleep, sitting, playing, and fighting.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60982ce549020014533033',
#    'text': 'The Chartreux is distinguished by a woolly blue-grey coat, a robust body poised over small paws, and full cheeks with a mouth that always appear to be smiling.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609852e549020014533036',
#    'text': "While Chartreux cats aren't very vocal, they are sociable and communicate through eye contact and body language.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60999ae549020014533038',
#    'text': 'Cats love playing with yarn, ribbons, and fishing-rode style toys. However, cats should not be left alone with anything that they could get tangled in.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a02e549020014533039',
#    'text': "All Scottish Folds descended from Susie, a white barn cat discovered in Scotland in the early 1960s. Susie sported the breed's folded ears – the result of a genetic mutation – and passed on the trait through breeding.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a90e54902001453303a',
#    'text': 'Mark Twain was undeniably an ailurophile. He had up to 19 cats at one time and gave them such memorable names as Beelzebub, Buffalo Bill, and Soapy Sal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c35cc2d7a200140f67ea',
#    'text': 'If you really want to treat your cat, get some lactose-free milk at the grocery store and offer some to the kitty.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c47dc2d7a200140f67ee',
#    'text': 'Abraham Lincoln, being the ailurophile that he was, once rescued three stray kittens and ensured that they were fed and found homes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c4eec2d7a200140f67ef',
#    'text': 'The Sphynx was originally known as the Canadian Hairless Cat. The breed originated in Toronto, and was renamed to Sphynx, a nod to the famous limestone sculpture in the Egyptian Desert.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c6a104fc2d7a200140f699f',
#    'text': 'A cat’s spine can rotate more than the spines of most other animals, and their vertebrae have a special, flexible, elastic cushioning on the disks, which gives it even more flexibility.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72d9b651021f001415f00c',
#    'text': 'Cats have been domesticated for around 4,000 years. While they were once valued for their hunting abilities, they are now valued for their companionship and loving behavior.',
#    'type': 'cat',
#    'user': {'_id': '5c6fd96df4256a001498a73f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72dbd851021f001415f010',
#    'text': 'The most popular pedigreed cat in North America is the Persian cat, followed by the Main Coon and the Siamese cat.',
#    'type': 'cat',
#    'user': {'_id': '5c72dbb751021f001415f00f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38afd60f1c57001592f127',
#    'type': 'cat',
#    'text': 'In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0310f1c57001592f128',
#    'type': 'cat',
#    'text': 'Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0c40f1c57001592f129',
#    'type': 'cat',
#    'text': 'The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b16c0f1c57001592f12b',
#    'type': 'cat',
#    'text': 'A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'type': 'cat',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5de780600013130015a3ccaf',
#    'type': 'cat',
#    'text': 'About one in two cats respond to catnip, and only develop a sensitivity to it at around 3 to 6 months of age.',
#    'user': {'_id': '5de681752c455b00153df068',
#     'name': {'first': 'Leonard', 'last': 'Wohlfarth'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '596f4f50a8d3440020e2d77d',
#    'text': 'Due to the controversy, though loved by most, the Kashmir is overlooked by many cat fanciers.',
#    'type': 'cat',
#    'user': {'_id': '596ea14ed4d9720020401f7b',
#     'name': {'first': 'Kenny', 'last': 'Corsig'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60b9e6acf530020f35871',
#    'text': 'The Egyptian Mau is the oldest breed of cat, and is the fastest pedigreed cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038bb98e3dbc001f71978d',
#    'text': 'The domestic cat (Felis catus) is a small, typically furry, carnivorous mammal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfc91b0810f0021748b92',
#    'text': 'Blackie became the richest cat in history when he inherited 15 million British Pounds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75e46ef087002174c284',
#    'text': 'Cats have about 130,000 hairs per square inch (20,155 hairs per square centimeter).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d767c6ef087002174c28a',
#    'text': 'Many Egyptians worshipped the goddess Bast, who had a woman’s body and a cat’s head.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d77446ef087002174c290',
#    'text': 'Approximately 1/3 of cat owners think their pets are able to read their minds.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c3ecc2d7a200140f67eb',
#    'text': 'The average female housecat could give birth to ove 100 kittens in her lifetime.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c422c2d7a200140f67ed',
# ...
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59b15b18d6eb960020d6767a',
#    'text': 'The place where Julius Caesar was murdered is now a cat sanctuary.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59ceab6d5c87bf0020b94e0a',
#    'text': 'The Bombay cat breed was developed to resemble a miniature panther.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59d297abc6671e0020957eb8',
#    'text': 'Cats use their whiskers to judge whether they’ll fit through a space.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038fba8e3dbc001f719794',
#    'text': 'Among domestic cats, males are more likely to fight than females.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a12460add20f9001fb45060',
#    'text': 'The softest part of a cat is most definitely its cheek area.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a36eb68ae877e0021ed79f3',
#    'text': "When a cat yawns, it's mouth opens so wide that you can count every tooth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab252c99ee00219e11c3',
#    'text': 'Cats can move their ears 180 degrees.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d78136ef087002174c292',
#    'text': 'Like humans, cats tend to favor one paw over another.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79496ef087002174c294',
#    'text': 'Approximately 40,000 people are bitten by cats in the U.S. annually.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911340508220014ccfe92',
#    'text': 'Kittens start to dream when they’re about a week old.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609ae8e54902001453303b',
#    'text': 'Approximately 40% of cats have a dominant paw. The rest are ambidextrous.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609945e549020014533037',
#    'text': 'Do you ever wake up in the middle of the night and find your cat sleeping on your head? Cat behavioral experts believe that cats are drawn to the warmth and the familiar scent of the owner. Resting on your head also keeps kitty safe from your arms and legs if you toss and turn through the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c7408a14dd87d001490f02b',
#    'text': "The cheetah is the only cat that doesn't have retractable claws.",
#    'type': 'cat',
#    'user': {'_id': '5c72e94751021f001415f012',
#     'name': {'first': 'Tests', 'last': 'HiQ'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c75f56272681400147b988a',
#    'text': 'There are only two escalators in the state of Wyoming.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c84248f731a60001540a193',
#    'text': 'When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn\'t been spayed, "elevator butt" could be a sign that she\'s ready to mate. The proper name for this stance is lordosis, and cats adopt it when they\'re in heat.',
#    'type': 'cat',
#    'user': {'_id': '5c7da4bd70008708fb17c88f',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c87d03dec1e5c0aa37e0a6b',
#    'type': 'cat',
#    'text': 'On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to 14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e83ff18f53272001515690c',
#    'type': 'cat',
#    'text': 'Cats are capable of walking very precisely because, like all felines, they directly register; that is, they place each hind paw (almost) directly in the print of the corresponding fore paw, minimizing noise and visible tracks. This also provides sure footing for their hind paws when they navigate rough terrain.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e10d7841c78ab0015bc5b15',
#    'type': 'cat',
#    'text': 'Some cats do not eat fish.',
#    'user': {'_id': '5e10d6e51c78ab0015bc5b14',
#     'name': {'first': 'Max', 'last': 'Bilohatnyuk'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e80e7cc2d4b850015003072',
#    'type': 'cat',
#    'text': 'Cats can climb on trees faster than squirels.',
#    'user': {'_id': '5e80e6c72d4b85001500306e',
#     'name': {'first': 'Łukasz', 'last': 'Wiktorko'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e19da391fd6150015fa7356',
#    'type': 'cat',
#    'text': '"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".',
#    'user': {'_id': '5e19d99e1fd6150015fa7353',
#     'name': {'first': 'Crystal Gale', 'last': 'Scott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e1efba858449a0015ce4783',
#    'type': 'cat',
#    'text': '"A house cat is faster than Usain Bolt.".',
#    'user': {'_id': '5e1efb5958449a0015ce4781',
#     'name': {'first': 'oyaji', 'last': '55'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}

# %%
# http://odata.wra.gov.tw/v4/RealtimeWaterLevel

r = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(r.text)
# Out:
# {'message': 'Sign in first'}
